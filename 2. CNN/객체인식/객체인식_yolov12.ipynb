# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinCY-Kim/Deeplearning/blob/main/%EA%B0%9D%EC%B2%B4%EC%9D%B8%EC%8B%9D_yolov12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 112.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ovndNchI3CK9b4Nm0Apn")
project = rf.workspace("alwork").project("firstproject-nrxek")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to firstproject-1 in yolov12:: 100%|██████████| 97/97 [00:00<00:00, 6345.69it/s]

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo12s.pt")

# %%
model.train(data="/content/firstproject-1/data.yaml")
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# 'metrics/mAP50(B)': 0.8538492063492064, 'metrics/mAP50-95(B)': 0.5635412784679088, 수치가 중요

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train/weights/best.pt")

model.predict("/content/firstproject-1/valid/images/-6_jpg.rf.67c1deb9987d3ceccf738f021b7ada31.jpg", save=True)
# Out:
# image 1/1 /content/firstproject-1/valid/images/-6_jpg.rf.67c1deb9987d3ceccf738f021b7ada31.jpg: 640x448 1 foot, 1 head, 66.6ms
# Speed: 1.6ms preprocess, 66.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'foot', 1: 'hand', 2: 'head'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ovndNchI3CK9b4Nm0Apn")
project = rf.workspace("alwork").project("fire_detection-iarpq")
version = project.version(2)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to fire_detection-2 in yolov12:: 100%|██████████| 113/113 [00:00<00:00, 5449.97it/s]

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolo12s.pt")

# %%
model.train(data="/content/fire_detection-2/data.yaml")
# Out:
# Ultralytics 8.3.192 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train2/weights/best.pt")

model.predict("/content/fire_detection-2/valid/images/202101914_1280_jpg.rf.7759c6daad13abdff5e57f6a4e2cc5dc.jpg", save=True)
# Out:
# image 1/1 /content/fire_detection-2/valid/images/202101914_1280_jpg.rf.7759c6daad13abdff5e57f6a4e2cc5dc.jpg: 640x640 10 fires, 20.9ms
# Speed: 1.9ms preprocess, 20.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'fire'}
#  obb: None
#  orig_img: array([[[ 99, 130, 253],
#          [ 99, 130, 253],
#          [ 98, 128, 253],
#          ...,
#          [ 67,  59,  66],
#          [ 67,  59,  66],
#          [ 67,  59,  66]],
#
#         [[ 99, 130, 253],
#          [ 99, 130, 253],
#          [ 98, 128, 253],
#          ...,
#          [ 67,  59,  66],
#          [ 67,  59,  66],
#          [ 67,  59,  66]],
#
#         [[ 99, 130, 253],
#          [ 99, 130, 253],
#          [ 98, 128, 253],
#          ...,
#          [ 67,  59,  66],
#          [ 67,  59,  66],
# ...
