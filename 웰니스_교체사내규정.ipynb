# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinCY-Kim/Deeplearning/blob/main/%EC%9B%B0%EB%8B%88%EC%8A%A4_%EA%B5%90%EC%B2%B4%EC%82%AC%EB%82%B4%EA%B7%9C%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIhub 웰니스 우울증 데이터셋으로 LLM을 PEFT 해보자

# %% [markdown]
# 1. 학습
#
# 2. 저장
#
# 3. 추론
#
# 까지 작성하여 공유링크 DM으로 제출
#
# GPT 쓰지 않고

# %%
# !pip install unsloth
# Out:
# Collecting unsloth
#   Downloading unsloth-2025.9.1-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.8 MB/s eta 0:00:00
# Collecting unsloth_zoo>=2025.9.1 (from unsloth)
#   Downloading unsloth_zoo-2025.9.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.8.0+cu126)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.32.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (25.0)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.9.31-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,>=4.51.3 in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.56.0)
# Collecting datasets<4.0.0,>=3.4.1 (from unsloth)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.0.2)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.10.1)
# Collecting trl!=0.15.0,!=0.19.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.22.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.17.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.29.5)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.34.4)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.35.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.23.0+cu126)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<4.0.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.1.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.11.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,>=4.51.3->unsloth) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,>=4.51.3->unsloth) (0.22.0)
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.9.1->unsloth) (0.10.0)
# Collecting cut_cross_entropy (from unsloth_zoo>=2025.9.1->unsloth)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2025.9.1->unsloth) (11.3.0)
# Collecting msgspec (from unsloth_zoo>=2025.9.1->unsloth)
#   Downloading msgspec-0.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth) (8.7.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (4.4.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (3.12.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro->unsloth) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro->unsloth) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<4.0.0,>=3.4.1->unsloth) (1.17.0)
# Downloading unsloth-2025.9.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 13.9 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 25.4 MB/s eta 0:00:00
# Downloading trl-0.22.2-py3-none-any.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.8/544.8 kB 29.3 MB/s eta 0:00:00
# Downloading unsloth_zoo-2025.9.2-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 19.9 MB/s eta 0:00:00
# Downloading xformers-0.0.32.post2-cp39-abi3-manylinux_2_28_x86_64.whl (117.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 MB 8.3 MB/s eta 0:00:00
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 10.4 MB/s eta 0:00:00
# Downloading tyro-0.9.31-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 kB 8.4 MB/s eta 0:00:00
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.19.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.6/213.6 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: shtab, msgspec, tyro, xformers, datasets, cut_cross_entropy, bitsandbytes, trl, unsloth_zoo, unsloth
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed bitsandbytes-0.47.0 cut_cross_entropy-25.1.1 datasets-3.6.0 msgspec-0.19.0 shtab-1.7.2 trl-0.22.2 tyro-0.9.31 unsloth-2025.9.1 unsloth_zoo-2025.9.2 xformers-0.0.32.post2

# %%
import pandas as pd

df = pd.read_csv("웰니스1.csv", encoding="utf-8")
df.head()
# Out:
#    구분                                     유저  \
# 0  지침                     사내에서 탕비실은 어디에 있나요?
# 1  지침        커피를 마시러 탕비실에 가고 싶은데, 길 좀 알려주세요.
# 2  지침                  탕비실은 회사 어디에 위치하고 있나요?
# 3  지침                     탕비실은 어떻게 찾아가야 하나요?
# 4  지침  점심 식사 후 탕비실을 이용하고 싶은데, 어디에 있는지 모르겠어요.
#
#                                    챗봇
# 0                   탕비실은 사무실 안쪽에 있어요.
# 1             탕비실은 사무실 안쪽으로 들어가시면 돼요.
# 2             사무실 안쪽에 탕비실이 마련되어 있습니다.
# 3        사무실 가장 안쪽으로 오시면 탕비실이 보일 거예요.
# 4  사무실 안쪽에 있으니 안쪽으로 가시면 찾으실 수 있을 거예요.

# %%
df
# Out:
#     구분                                     유저  \
# 0   지침                     사내에서 탕비실은 어디에 있나요?
# 1   지침        커피를 마시러 탕비실에 가고 싶은데, 길 좀 알려주세요.
# 2   지침                  탕비실은 회사 어디에 위치하고 있나요?
# 3   지침                     탕비실은 어떻게 찾아가야 하나요?
# 4   지침  점심 식사 후 탕비실을 이용하고 싶은데, 어디에 있는지 모르겠어요.
# ..  ..                                    ...
# 95  지침            징계 절차에 대한 규정은 어디에서 찾아야 하나요?
# 96  지침                     회사 자산 관리 규정이 궁금해요.
# 97  지침                 내부 감사 규정은 어디서 볼 수 있나요?
# 98  지침         윤리 경영에 대한 회사 방침은 어디에 명시되어 있나요?
# 99  지침           정보 통신 이용에 대한 사내 법규는 어디에 있나요?
#
#                                                챗봇
# 0                               탕비실은 사무실 안쪽에 있어요.
# 1                         탕비실은 사무실 안쪽으로 들어가시면 돼요.
# 2                         사무실 안쪽에 탕비실이 마련되어 있습니다.
# 3                    사무실 가장 안쪽으로 오시면 탕비실이 보일 거예요.
# 4              사무실 안쪽에 있으니 안쪽으로 가시면 찾으실 수 있을 거예요.
# ..                                            ...
# 95     징계 절차에 대한 사내 법규는 회사 사이트 '법규' 탭에서 확인 가능합니다.
# 96     회사 자산 관리 사내 법규는 회사 사이트 '법규' 탭에 상세히 나와 있어요.
# 97           내부 감사 관련 사내 법규는 회사 사이트 '법규' 탭에 있습니다.
# 98    윤리 경영 관련 사내 법규는 회사 사이트 '법규' 탭에서 확인할 수 있습니다.
# 99  정보 통신 이용에 관한 사내 법규는 회사 사이트 '법규' 탭에서 보실 수 있어요.
#
# [100 rows x 3 columns]

# %%
df
# Out:
#               구분                            유저  \
# 0        감정/의기소침                    다 제 잘못이에요.
# 1      배경/부모/아버지     어렸을 때부터 엄마보다는 아빠랑 더 친했어요.
# 2        증상/체중증가                     몸무게도 늘고요.
# 3          감정/눈물                 눈물이 날 거 같더라고.
# 4       배경/직장/이직  회사를 옮기면서 직급도 올라서, 지금은 과장이에요.
# ..           ...                           ...
# 852   배경/사고/교통사고    차 찌그러지는 소리와 함께 잠깐 정신을 잃었어.
# 853     배경/부모/갈등        엄마랑 아빠 사이가 그닥 좋진 않았어.
# 854  배경/문제/불편감/옷      어릴 때부터 옷 입는 게 불편하고 싫었어요.
# 855     감정/걱정/미래           앞으로 집은 어떻게 사나 싶어요.
# 856     배경/친구/배신       얼마 전에 걔한테 진짜 크게 배신 당했어.
#
#                                                챗봇
# 0    낚시를 하듯이 조금 더 먼 곳을 보고, 조금 더 마음을 비우면 편안해질 거예요.
# 1                         그러시군요. 아버지에 대해 더 들려주세요.
# 2                 체중이 단기간에 많이 늘어나면 건강에 좋지 않다고 해요.
# 3    감수성이 풍부하다는 증거 같아요. 눈물이 많은 사람 중에 나쁜 사람은 없잖아요.
# 4                      그렇군요. 새로운 환경이라 적응이 필요하겠어요.
# ..                                            ...
# 852                                   정말 놀라셨겠어요.
# 853                             가까운 사이라 더 힘들었겠어요.
# 854                   아, 그러시군요. 꺼끄러운 면이 닿으면 불편하죠.
# 855         언젠가는 나아질 거라는 믿음이 사람을 버티게 만들어주는 것 같아요.
# 856   믿었던 사람에게 배신 당하는 것만큼 힘든 게 없는데 정말 고민이 많으셨겠어요.
#
# [857 rows x 3 columns]

# %%
# Unsloth 라이브러리에서 FastLanguageModel을 임포트
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 # 최대 시퀀스 길이를 설정 ( 텍스트의 최대 길이를 지정)
dtype = None  # 자동 감지를 위해 None 설정. Tesla T4는 Float16, Ampere+는 Bfloat16 사용. 모델의 파라미터를 저장할 데이터 타입
load_in_4bit = True  # 메모리 사용량을 줄이기 위해 4비트 양자화 사용. 다만 양자화에 따른 손실이 있어서 필요에 따라 False로 설정 가능

# 사전 학습된 모델과 토크나이저 로드
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-1B-bnb-4bit",  # 사용할 모델 이름
    max_seq_length = max_seq_length,         # 설정한 최대 시퀀스 길이
    dtype = dtype,                           # 데이터 타입 설정
    load_in_4bit = load_in_4bit,             # 4비트 양자화 여부
)
# Out:
# ==((====))==  Unsloth 2025.9.1: Fast Llama patching. Transformers: 4.56.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
# PEFT(파라미터 효율적 파인튜닝) 모델 설정
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,  # LoRA 랭크 설정. 8, 16, 32, 64, 128 권장. r 값이 클수록 모델이 더 많은 정보를 학습할 수 있지만, 너무 크면 메모리를 많이 사용
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],  # PEFT 적용할 모듈 목록. 모델의 특정 부분(모듈)에만 학습
    lora_alpha = 16,        # LoRA 알파 설정 LoRA라는 기술이 얼마나 강하게 작용할지 조절
    lora_dropout = 0,       # LoRA 드롭아웃 설정. 0으로 최적화
    bias = "none",          # 바이어스 설정. "none"으로 최적화

    # "unsloth" 사용 시 VRAM 절약 및 배치 사이즈 2배 증가
    # 학습할 때 메모리를 절약하는 방법을 사용하는 설정
    use_gradient_checkpointing = "unsloth",  # 매우 긴 컨텍스트를 위해 "unsloth" 설정
    random_state = 3407,    # 랜덤 시드 설정
    use_rslora = False,     # 랭크 안정화 LoRA 사용 여부
    loftq_config = None,    # LoftQ 설정 (사용하지 않음)
)
# Out:
# Unsloth 2025.9.1 patched 16 layers with 16 QKV layers, 16 O layers and 16 MLP layers.

# %%
# 모델에게 주어질 텍스트의 형식을 정의
alpaca_prompt = """Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction:
{}

### Response:
{}"""

# 맨윗줄: 모델에게 앞으로 제공될 지시사항을 기반으로 적절한 응답을 작성하라고 말함.
# 모델이 어떤 작업을 수행해야 하는지 명확히 이해할 수 있도록 도와줌
# Instruction:은 지시사항이 제공될 부분
# Response:는 모델이 생성해야 할 응답이 제공될 부분

# EOS 토큰 가져오기 (생성 종료를 위해 필요)
EOS_TOKEN = tokenizer.eos_token  # 반드시 EOS_TOKEN을 추가해야 함
EOS_TOKEN
# Out:
# '<|end_of_text|>'

# %%
# 프롬프트 포맷팅 함수 정의
def formatting_prompts_func(examples):
    instructions = examples["유저"]  # 데이터셋의 'instruction' 필드
    outputs      = examples["챗봇"]       # 데이터셋의 'output' 필드
    texts = []
    for instruction, output in zip(instructions, outputs):
                                                           # EOS_TOKEN을 추가하지 않으면 생성이 무한히 계속됨
        text = alpaca_prompt.format(instruction, output) + EOS_TOKEN  # 프롬프트 형식에 맞게 텍스트 생성
        texts.append(text)
    return { "text" : texts, }  # 'text' 필드로 반환

from datasets import load_dataset  # Hugging Face datasets 라이브러리 임포트

# 데이터셋 로드 (Teddy Lee의 QA 데이터셋 미니 버전)
#dataset = load_dataset("teddylee777/QA-Dataset-mini", split = "train")

# 프롬프트 포맷팅 함수 적용하여 데이터셋 변환
#dataset = dataset.map(formatting_prompts_func, batched = True,)

from datasets import load_dataset
dataset = load_dataset( "csv", data_files = "/content/웰니스1.csv", split = "train")
dataset = dataset.map(formatting_prompts_func, batched=True)

# 예제 엑셀 형태로 데이터셋을 만든다면?
# from datasets import load_dataset
# dataset = load_dataset( "csv", data_files = "data.csv", split = "train")
# dataset = dataset.map(formatting_prompts_func, batched=True)
#
#

# %%
dataset['text'][:5]
# Out:
# ['Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n사내에서 탕비실은 어디에 있나요?\n\n### Response:\n탕비실은 사무실 안쪽에 있어요.<|end_of_text|>',
#  'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n커피를 마시러 탕비실에 가고 싶은데, 길 좀 알려주세요.\n\n### Response:\n탕비실은 사무실 안쪽으로 들어가시면 돼요.<|end_of_text|>',
#  'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n탕비실은 회사 어디에 위치하고 있나요?\n\n### Response:\n사무실 안쪽에 탕비실이 마련되어 있습니다.<|end_of_text|>',
#  'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n탕비실은 어떻게 찾아가야 하나요?\n\n### Response:\n사무실 가장 안쪽으로 오시면 탕비실이 보일 거예요.<|end_of_text|>',
#  'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\n점심 식사 후 탕비실을 이용하고 싶은데, 어디에 있는지 모르겠어요.\n\n### Response:\n사무실 안쪽에 있으니 안쪽으로 가시면 찾으실 수 있을 거예요.<|end_of_text|>']

# %%
## 학습 설정
from trl import SFTTrainer  # TRL 라이브러리에서 SFTTrainer 임포트
from transformers import TrainingArguments  # 트랜스포머 라이브러리에서 TrainingArguments 임포트
from unsloth import is_bfloat16_supported  # BFloat16 지원 여부 확인 함수 임포트

# SFTTrainer 인스턴스 생성
trainer = SFTTrainer(
    model = model,                           # 학습할 모델
    tokenizer = tokenizer,                   # 사용할 토크나이저
    train_dataset = dataset,                 # 학습할 데이터셋 ★★★★★★★★
    dataset_text_field = "text",             # 데이터셋의 텍스트 필드 이름 ★★★★★★★★
    max_seq_length = max_seq_length,         # 최대 시퀀스 길이
    dataset_num_proc = 2,                    # 데이터셋 전처리에 사용할 프로세스 수 cpu
    packing = False,                         # 짧은 시퀀스의 경우 packing을 비활성화 (학습 속도 5배 향상 가능)
    args = TrainingArguments(
        per_device_train_batch_size = 2,     # 디바이스 당 배치 사이즈
        gradient_accumulation_steps = 4,     # 그래디언트 누적 단계 수
        warmup_steps = 5,                     # 워밍업 스텝 수
        num_train_epochs = 1,               # 전체 학습 에폭 수 설정 가능
        # max_steps = 60,                       # 최대 학습 스텝 수
        learning_rate = 2e-4,                 # 학습률
        fp16 = not is_bfloat16_supported(),   # BFloat16 지원 여부에 따라 FP16 사용
        bf16 = is_bfloat16_supported(),       # BFloat16 사용 여부
        logging_steps = 1,                    # 로깅 빈도
        optim = "adamw_8bit",                  # 옵티마이저 설정 (8비트 AdamW)
        weight_decay = 0.01,                  # 가중치 감쇠
        lr_scheduler_type = "linear",         # 학습률 스케줄러 타입
        seed = 3407,                           # 랜덤 시드 설정
        output_dir = "outputs",                # 출력 디렉토리
    ),
)

## 학습 실행
trainer_stats = trainer.train()  # 모델 학습 시작 # 3d6e4b9a0ddcd9edfafad59dcde0fd8c666954fd
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/100 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 100 | Num Epochs = 1 | Total steps = 13
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 11,272,192 of 1,247,086,592 (0.90% trained)
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: alpacoosh (alpacoosh-alpaco) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.5s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/wandb/run-20250905_052046-k4k0qlif</code>
# Syncing run <strong><a href='https://wandb.ai/alpacoosh-alpaco/huggingface/runs/k4k0qlif' target="_blank">feasible-pyramid-44</a></strong> to <a href='https://wandb.ai/alpacoosh-alpaco/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alpacoosh-alpaco/huggingface' target="_blank">https://wandb.ai/alpacoosh-alpaco/huggingface</a>
#  View run at <a href='https://wandb.ai/alpacoosh-alpaco/huggingface/runs/k4k0qlif' target="_blank">https://wandb.ai/alpacoosh-alpaco/huggingface/runs/k4k0qlif</a>
#     <div>
#
#       <progress value='13' max='13' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13/13 00:11, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.581300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.500000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.686800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.534700</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.311000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.829500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.649500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.471800</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.171700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.991400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.859900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.812400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.959700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# 모델 저장 로컬폴더에다가 저장하는 방식
model.save_pretrained("웰니스1")  # Local saving
tokenizer.save_pretrained("웰니스1")

# 이 이외에 허깅페이스나 다른 hub에 push해서 저장하는 방법이 있음
# 다만, 업로드 속도와 다운로드 속도를 고려해야함.
# Out:
# ('웰니스1/tokenizer_config.json',
#  '웰니스1/special_tokens_map.json',
#  '웰니스1/tokenizer.json')

# %%
from unsloth import FastLanguageModel
import torch

# 저장된 경로 지정
save_directory = "웰니스1"

# 모델과 토크나이저 불러오기
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = save_directory,
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,  # 양자화 옵션을 동일하게 설정
)
# Out:
# ==((====))==  Unsloth 2025.9.1: Fast Llama patching. Transformers: 4.56.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
# 추론해보기
FastLanguageModel.for_inference(model)  # 네이티브 2배 빠른 추론 활성화

# 추론을 위한 입력 준비
inputs = tokenizer(
[
    alpaca_prompt.format(
        "사내 법규는 어디에 있어.", # 인스트럭션 (명령어)
        "", # 출력 - 생성할 답변을 비워둠
    )
], return_tensors = "pt").to("cuda")  # 텐서를 PyTorch 형식으로 변환하고 GPU로 이동

from transformers import TextStreamer  # 텍스트 스트리밍을 위한 TextStreamer 임포트

text_streamer = TextStreamer(tokenizer)  # 토크나이저를 사용하여 스트리머 초기화

# 모델을 사용하여 텍스트 생성 및 스트리밍 출력
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)  # 최대 128개의 새로운 토큰 생성
# Out:
# <|begin_of_text|>Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# 사내 법규는 어디에 있어.
#
# ### Response:
# 사내 법규는 회사 홈페이지에 게재되어 있습니다.<|end_of_text|>

# %%
# 답변만 추출
generated_text = tokenizer.decode(_[0], skip_special_tokens=True)
generated_text.split("### Response:")[1].strip()
# Out:
# '사내 법규는 회사 홈페이지에 게재되어 있습니다.'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !zip -r /content/well.zip /content/
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_update_check.json (deflated 23%)
#   adding: content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: content/.config/default_configs.db (deflated 98%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/config_sentinel (stored 0%)
#   adding: content/.config/gce (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2025.09.03/ (stored 0%)
#   adding: content/.config/logs/2025.09.03/13.35.50.564372.log (deflated 58%)
#   adding: content/.config/logs/2025.09.03/13.35.51.306217.log (deflated 56%)
#   adding: content/.config/logs/2025.09.03/13.35.39.928561.log (deflated 86%)
#   adding: content/.config/logs/2025.09.03/13.35.10.219821.log (deflated 93%)
#   adding: content/.config/logs/2025.09.03/13.35.31.467623.log (deflated 58%)
#   adding: content/.config/logs/2025.09.03/13.35.41.650830.log (deflated 58%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/웰니스1/ (stored 0%)
#   adding: content/웰니스1/tokenizer.json (deflated 85%)
#   adding: content/웰니스1/adapter_config.json (deflated 57%)
#   adding: content/웰니스1/README.md (deflated 65%)
#   adding: content/웰니스1/special_tokens_map.json (deflated 71%)
#   adding: content/웰니스1/tokenizer_config.json (deflated 96%)
#   adding: content/웰니스1/adapter_model.safetensors (deflated 8%)
#   adding: content/huggingface_tokenizers_cache/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/refs/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/refs/main (deflated 5%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/blobs/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/blobs/68b10c7f0a479eae0c358eac6a14959b3f9acdf1 (deflated 71%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/blobs/8a071772876bc826e78c6649464bf838205fe5d1 (deflated 96%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/blobs/6b9e4e7fb171f92fd137b777cc2714bf87d11576700a1dcd7a399e7bbe39537b (deflated 85%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/.no_exist/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/.no_exist/c19aba40b57098abca2320dbbb84026dcc24cae4/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/.no_exist/c19aba40b57098abca2320dbbb84026dcc24cae4/chat_template.jinja (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/.no_exist/c19aba40b57098abca2320dbbb84026dcc24cae4/added_tokens.json (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/.no_exist/c19aba40b57098abca2320dbbb84026dcc24cae4/tokenizer.model (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/snapshots/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/snapshots/c19aba40b57098abca2320dbbb84026dcc24cae4/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/snapshots/c19aba40b57098abca2320dbbb84026dcc24cae4/tokenizer.json (deflated 85%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/snapshots/c19aba40b57098abca2320dbbb84026dcc24cae4/special_tokens_map.json (deflated 71%)
#   adding: content/huggingface_tokenizers_cache/models--unsloth--llama-3.2-1b-bnb-4bit/snapshots/c19aba40b57098abca2320dbbb84026dcc24cae4/tokenizer_config.json (deflated 96%)
#   adding: content/huggingface_tokenizers_cache/.locks/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3.2-1b-bnb-4bit/ (stored 0%)
#   adding: content/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3.2-1b-bnb-4bit/68b10c7f0a479eae0c358eac6a14959b3f9acdf1.lock (stored 0%)
#   adding: content/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3.2-1b-bnb-4bit/8a071772876bc826e78c6649464bf838205fe5d1.lock (stored 0%)
#   adding: content/huggingface_tokenizers_cache/.locks/models--unsloth--llama-3.2-1b-bnb-4bit/6b9e4e7fb171f92fd137b777cc2714bf87d11576700a1dcd7a399e7bbe39537b.lock (stored 0%)
#   adding: content/wandb/ (stored 0%)
#   adding: content/wandb/latest-run/ (stored 0%)
#   adding: content/wandb/latest-run/files/ (stored 0%)
#   adding: content/wandb/latest-run/files/output.log (deflated 73%)
#   adding: content/wandb/latest-run/files/wandb-metadata.json (deflated 40%)
#   adding: content/wandb/latest-run/files/requirements.txt (deflated 56%)
#   adding: content/wandb/latest-run/tmp/ (stored 0%)
#   adding: content/wandb/latest-run/tmp/code/ (stored 0%)
#   adding: content/wandb/latest-run/logs/ (stored 0%)
#   adding: content/wandb/latest-run/logs/debug.log (deflated 73%)
#   adding: content/wandb/latest-run/logs/debug-internal.log (deflated 69%)
#   adding: content/wandb/latest-run/logs/debug-core.log (deflated 56%)
#   adding: content/wandb/latest-run/run-k4k0qlif.wandb (deflated 70%)
#   adding: content/wandb/debug.log (deflated 73%)
#   adding: content/wandb/debug-internal.log (deflated 69%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/ (stored 0%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/files/ (stored 0%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/files/output.log (deflated 73%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/files/wandb-metadata.json (deflated 40%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/files/requirements.txt (deflated 56%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/tmp/ (stored 0%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/tmp/code/ (stored 0%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/logs/ (stored 0%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/logs/debug.log (deflated 73%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/logs/debug-internal.log (deflated 69%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/logs/debug-core.log (deflated 56%)
#   adding: content/wandb/run-20250905_052046-k4k0qlif/run-k4k0qlif.wandb (deflated 70%)
#   adding: content/웰니스1.csv (deflated 76%)
#   adding: content/unsloth_compiled_cache/ (stored 0%)
#   adding: content/unsloth_compiled_cache/UnslothPRMTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/UnslothKTOTrainer.py (deflated 79%)
#   adding: content/unsloth_compiled_cache/UnslothNashMDTrainer.py (deflated 77%)
#   adding: content/unsloth_compiled_cache/UnslothGKDTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/UnslothGRPOTrainer.py (deflated 77%)
#   adding: content/unsloth_compiled_cache/UnslothRewardTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/UnslothXPOTrainer.py (deflated 78%)
#   adding: content/unsloth_compiled_cache/UnslothPPOTrainer.py (deflated 78%)
#   adding: content/unsloth_compiled_cache/UnslothIterativeSFTTrainer.py (deflated 77%)
#   adding: content/unsloth_compiled_cache/UnslothSFTTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/UnslothAlignPropTrainer.py (deflated 73%)
#   adding: content/unsloth_compiled_cache/UnslothORPOTrainer.py (deflated 77%)
#   adding: content/unsloth_compiled_cache/UnslothRLOOTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/UnslothDDPOTrainer.py (deflated 75%)
#   adding: content/unsloth_compiled_cache/UnslothBCOTrainer.py (deflated 78%)
#   adding: content/unsloth_compiled_cache/UnslothDPOTrainer.py (deflated 78%)
#   adding: content/unsloth_compiled_cache/UnslothOnlineDPOTrainer.py (deflated 76%)
#   adding: content/unsloth_compiled_cache/__pycache__/ (stored 0%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothXPOTrainer.cpython-312.pyc (deflated 53%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothDPOTrainer.cpython-312.pyc (deflated 59%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothOnlineDPOTrainer.cpython-312.pyc (deflated 54%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothGKDTrainer.cpython-312.pyc (deflated 52%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothPRMTrainer.cpython-312.pyc (deflated 53%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothAlignPropTrainer.cpython-312.pyc (deflated 57%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothSFTTrainer.cpython-312.pyc (deflated 54%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothRewardTrainer.cpython-312.pyc (deflated 52%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothGRPOTrainer.cpython-312.pyc (deflated 58%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothDDPOTrainer.cpython-312.pyc (deflated 57%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothORPOTrainer.cpython-312.pyc (deflated 55%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothNashMDTrainer.cpython-312.pyc (deflated 52%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothKTOTrainer.cpython-312.pyc (deflated 58%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothPPOTrainer.cpython-312.pyc (deflated 54%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothCPOTrainer.cpython-312.pyc (deflated 56%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothRLOOTrainer.cpython-312.pyc (deflated 57%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothIterativeSFTTrainer.cpython-312.pyc (deflated 54%)
#   adding: content/unsloth_compiled_cache/__pycache__/UnslothBCOTrainer.cpython-312.pyc (deflated 57%)
#   adding: content/unsloth_compiled_cache/UnslothCPOTrainer.py (deflated 77%)
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/README.md (deflated 43%)
#   adding: content/outputs/runs/ (stored 0%)
#   adding: content/outputs/runs/Sep05_05-20-10_73611fc0f0dc/ (stored 0%)
#   adding: content/outputs/runs/Sep05_05-20-10_73611fc0f0dc/events.out.tfevents.1757049627.73611fc0f0dc.274.0 (deflated 62%)
#   adding: content/outputs/checkpoint-13/ (stored 0%)
#   adding: content/outputs/checkpoint-13/tokenizer.json (deflated 85%)
#   adding: content/outputs/checkpoint-13/adapter_config.json (deflated 57%)
#   adding: content/outputs/checkpoint-13/optimizer.pt (deflated 10%)
#   adding: content/outputs/checkpoint-13/trainer_state.json (deflated 72%)
#   adding: content/outputs/checkpoint-13/scaler.pt (deflated 64%)
#   adding: content/outputs/checkpoint-13/training_args.bin (deflated 53%)
#   adding: content/outputs/checkpoint-13/README.md (deflated 65%)
#   adding: content/outputs/checkpoint-13/scheduler.pt (deflated 62%)
#   adding: content/outputs/checkpoint-13/special_tokens_map.json (deflated 71%)
#   adding: content/outputs/checkpoint-13/tokenizer_config.json (deflated 96%)
#   adding: content/outputs/checkpoint-13/rng_state.pth (deflated 26%)
#   adding: content/outputs/checkpoint-13/adapter_model.safetensors (deflated 8%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/README.md (deflated 39%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
